# %%
import torch
import torch.nn as nn
from typing import Dict, List, Tuple, Any
from tabpfn.scripts.model_builder import get_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import torch.nn as nn
#       3 from typing import Dict, List, Tuple, Any
# ----> 4 from tabpfn.interfaces.unsupervised import TabPFNUnsupervisedModel
#
# ModuleNotFoundError: No module named 'tabpfn.interfaces'

# %%
get_model()

# %%
type(model[0])
# Out:
# collections.OrderedDict

# %%
emsize = 512
nhead = 4
nhid = 1024
nlayers = 12

# %%
from pfn_hooks import PFNHookManager
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from pfn_hooks import PFNHookManager
#
# File ~/Desktop/conformal_ood/tabpfn_ood/pfn_hooks.py:9
#       5 from typing import Dict, List, Tuple, Any
#       7 sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(__file__), '..', 'tabpfn_repo')))
# ----> 9 from tabpfn.scripts.model_builder import load_model_only_inference
#      11 class PFNHookManager:
#      12     """
#      13     Manages loading a pre-trained PFN model, registering forward hooks on its
#      14     TransformerEncoderLayers and MultiheadAttention modules, and caching activations
#      15     and attention weights during a forward pass.
#      16     """
#
# ModuleNotFoundError: No module named 'tabpfn.scripts'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 4
#       2 import sys
#       3 sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', 'tabpfn_repo')))
# ----> 4 from tabpfn.scripts.model_builder import load_model_only_inference
#
# ModuleNotFoundError: No module named 'tabpfn.scripts'

# %%
os.path.abspath(os.path.join(os.getcwd(), '..', 'tabpfn'))
# Out:
# '/home/psquare_a6000/Desktop/conformal_ood/tabpfn'

# %%
os.getcwd()
# Out:
# '/home/psquare_a6000/Desktop/conformal_ood/tabpfn_ood'
